# %% [markdown]
# # Project 6 - Boat & Yacht Sales

# %% [markdown]
# Importing Visualization Libraries and Data
# ---

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import folium
import json

# %%
# create a path
path = r'C:\Users\niels\Documents\Sales Boat\Data Source'

# %%
# load data
df = pd.read_csv(os.path.join(path,'boat_data_cleaned_V2.csv'), index_col = False)

# %% [markdown]
# Load the geojson data for european country boundaries
# ---

# %%
europe_json = json.load(open("europe.geo.json", "r", encoding="utf-8"))

# %% [markdown]
# Data wrangling to show accurate data
# ---

# %%
df = pd.read_csv(os.path.join(path,'boat_data_cleaned_V2.csv'), index_col = False)
country_counts = df.Country.value_counts()
countries_to_remove = country_counts[country_counts <= 1]
df = df[~df.Country.isin(countries_to_remove.index)]

# %% [markdown]
# Mapping the country name in our dataset to the name contained in the json file
# ---

# %%
df.Country = df.Country.apply(lambda s: s.replace("Croatia (Hrvatska)", "Croatia").replace("Slovak Republic", "Slovakia"))

df_countries = set(df.Country.unique())
json_countries = set([feature["properties"]["name"] for feature in europe_json['features']])
df_countries.difference(json_countries)
# Out:
# {'Malta', 'Turkey'}

# %% [markdown]
# Country name differences between the 2 datasets
# ---

# %%
m = folium.Map(location=[46.8155135,8.224471999999992],zoom_start=5, width=800, height=500, control_scale=True)
choropleth_nb = folium.Choropleth(
    geo_data = europe_json,
    data=df,
    columns = ['Country', 'Number of views last 7 days'],
    key_on = 'feature.properties.name',
    fill_color = "Reds",
    fill_opacity = .7,
    line_opacity = .5,
    legend_name = 'Number of views last 7 days',
    highlight = True,
    name='choropleth',
    nan_fill_color="rgba(0, 0, 0, 0)"
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9b104fc0694e79b60ca08d0ff1912f4 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9b104fc0694e79b60ca08d0ff1912f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9b104fc0694e79b60ca08d0ff1912f4 = L.map(
#                 &quot;map_a9b104fc0694e79b60ca08d0ff1912f4&quot;,
#                 {
#                     center: [46.8155135, 8.224471999999992],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a9b104fc0694e79b60ca08d0ff1912f4);
#
#
#
#
#
#             var tile_layer_8fa83b4fad4967c05b4839d9397fddcf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9b104fc0694e79b60ca08d0ff1912f4);
#
#
#             var choropleth_9d06f3371f7526afd8bb6fcb20a9cf63 = L.featureGroup(
#                 {}
#             ).addTo(map_a9b104fc0694e79b60ca08d0ff1912f4);
#
#
#         function geo_json_f0e1f3cb10a419a082559403d81e09c3_styler(feature) {
#             switch(feature.properties.sovereignt) {
#                 case &quot;France&quot;: case &quot;Poland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Germany&quot;: case &quot;Switzerland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Belgium&quot;: case &quot;Denmark&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#de2d26&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Finland&quot;: case &quot;Spain&quot;: case &quot;Greece&quot;: case &quot;Netherlands&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Austria&quot;: case &quot;Croatia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc9272&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Italy&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgba(0, 0, 0, 0)&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_f0e1f3cb10a419a082559403d81e09c3_highlighter(feature) {
#             switch(feature.properties.sovereignt) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8999999999999999, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_f0e1f3cb10a419a082559403d81e09c3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_f0e1f3cb10a419a082559403d81e09c3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f0e1f3cb10a419a082559403d81e09c3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f0e1f3cb10a419a082559403d81e09c3 = L.geoJson(null, {
#                 onEachFeature: geo_json_f0e1f3cb10a419a082559403d81e09c3_onEachFeature,
#
#                 style: geo_json_f0e1f3cb10a419a082559403d81e09c3_styler,
#         });
#
#         function geo_json_f0e1f3cb10a419a082559403d81e09c3_add (data) {
#             geo_json_f0e1f3cb10a419a082559403d81e09c3
#                 .addData(data)
#                 .addTo(choropleth_9d06f3371f7526afd8bb6fcb20a9cf63);
#         }
#             geo_json_f0e1f3cb10a419a082559403d81e09c3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-51.65779741067889, 4.156232408053029], [-52.249337531123956, 3.241094468596245], [-52.55642473001842, 2.504705308437053], [-52.939657151894956, 2.124857692875636], [-53.41846513529531, 2.053389187015981], [-53.554839240113544, 2.334896551925951], [-53

# %% [markdown]
# ### Does the analysis answer any of your existing research questions?
#
# This analysis shows us in which country have the most views these last 7 days. It's telling us important information regarding the location of boats that are interesting potential customers. This is a key indicator for the sales team.
#
# ### Does the analysis lead you to any new research questions?
#
# This analysis could lead to question like why Italy has the most viewed boats the last 7 days ?

# %%
m = folium.Map(location=[46.8155135,8.224471999999992],zoom_start=5, width=800, height=500, control_scale=True)
choropleth_price = folium.Choropleth(
    geo_data = europe_json,
    data=df,
    columns = ['Country', 'EUR_price'],
    key_on = 'feature.properties.name',
    fill_color = "Reds",
    fill_opacity = .8,
    line_opacity = .5,
    legend_name = 'Price (EUR)',
    highlight = True,
    name='choropleth',
    nan_fill_color="rgba(0, 0, 0, 0)"
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcef89c5eca3e6437d7939daae7a9dd1 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcef89c5eca3e6437d7939daae7a9dd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcef89c5eca3e6437d7939daae7a9dd1 = L.map(
#                 &quot;map_bcef89c5eca3e6437d7939daae7a9dd1&quot;,
#                 {
#                     center: [46.8155135, 8.224471999999992],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bcef89c5eca3e6437d7939daae7a9dd1);
#
#
#
#
#
#             var tile_layer_984eac9790247130ea4435b60f9e2174 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcef89c5eca3e6437d7939daae7a9dd1);
#
#
#             var choropleth_64aa5a9f99c0cac419fa8583c637cd80 = L.featureGroup(
#                 {}
#             ).addTo(map_bcef89c5eca3e6437d7939daae7a9dd1);
#
#
#         function geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_styler(feature) {
#             switch(feature.properties.sovereignt) {
#                 case &quot;France&quot;: case &quot;Germany&quot;: case &quot;Spain&quot;: case &quot;Denmark&quot;: case &quot;Poland&quot;: case &quot;Austria&quot;: case &quot;Italy&quot;: case &quot;Switzerland&quot;: case &quot;Netherlands&quot;: case &quot;Croatia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Belgium&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Finland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#de2d26&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Greece&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgba(0, 0, 0, 0)&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_highlighter(feature) {
#             switch(feature.properties.sovereignt) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4 = L.geoJson(null, {
#                 onEachFeature: geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_onEachFeature,
#
#                 style: geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_styler,
#         });
#
#         function geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_add (data) {
#             geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4
#                 .addData(data)
#                 .addTo(choropleth_64aa5a9f99c0cac419fa8583c637cd80);
#         }
#             geo_json_47cc9af4f3b0b8e93fb6ffdea187e8d4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-51.65779741067889, 4.156232408053029], [-52.249337531123956, 3.241094468596245], [-52.55642473001842, 2.504705308437053], [-52.939657151894956, 2.124857692875636], [-53.41846513529531, 2.053389187015981], [-53.554839240113544, 2.334896551925951], [-53.77852067728892, 2.376702785650082], [-54.08806250671725, 2.105556545414629], [-54.524754197799716, 2.311848863123785], [-54.2697051662232, 2.732391669115046], [-54.181726040246275, 3.189779771330421], [-54.00693050801901, 3.620037746592558], [-54.399542202356514, 4.212611395683467], [-54.47863298197923, 4.896755682795586], [-53.9580446030709, 5.756548163267765], [-53.618452928264844, 5.646529038918374], [-52.88214128275409,

# %% [markdown]
# ### Does the analysis answer any of your existing research questions?
#
# This analysis shows us in which country have the most expensive boats are located. It give us relevant information about the prices all over the market that is a key topics either for customers or sales team.
#
# ### Does the analysis lead you to any new research questions?
#
# This analysis could lead to question like why Greece and Sweden has the most expensive boats in the market ?

# %%
m = folium.Map(location=[46.8155135,8.224471999999992],zoom_start=5, width=800, height=500, control_scale=True)
choropleth_price = folium.Choropleth(
    geo_data = europe_json,
    data=df,
    columns = ['Country', 'Year Built'],
    key_on = 'feature.properties.name',
    fill_color = "Reds",
    fill_opacity = .8,
    line_opacity = .5,
    legend_name = 'Year Built',
    highlight = True,
    name='choropleth',
    nan_fill_color="rgba(0, 0, 0, 0)"
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f48e36f1111b611d2418cc7a0dc7fd5 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f48e36f1111b611d2418cc7a0dc7fd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f48e36f1111b611d2418cc7a0dc7fd5 = L.map(
#                 &quot;map_5f48e36f1111b611d2418cc7a0dc7fd5&quot;,
#                 {
#                     center: [46.8155135, 8.224471999999992],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5f48e36f1111b611d2418cc7a0dc7fd5);
#
#
#
#
#
#             var tile_layer_f12f6221704f148c4b36a90c62286521 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f48e36f1111b611d2418cc7a0dc7fd5);
#
#
#             var choropleth_7d144fcc19d4cb1876c5d0be532f397b = L.featureGroup(
#                 {}
#             ).addTo(map_5f48e36f1111b611d2418cc7a0dc7fd5);
#
#
#         function geo_json_a915811013e93e19a697fb7454e2db6a_styler(feature) {
#             switch(feature.properties.sovereignt) {
#                 case &quot;France&quot;: case &quot;Greece&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Germany&quot;: case &quot;Poland&quot;: case &quot;Italy&quot;: case &quot;Switzerland&quot;: case &quot;Netherlands&quot;: case &quot;Croatia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Belgium&quot;: case &quot;Finland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#de2d26&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Spain&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Denmark&quot;: case &quot;Austria&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgba(0, 0, 0, 0)&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_a915811013e93e19a697fb7454e2db6a_highlighter(feature) {
#             switch(feature.properties.sovereignt) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_a915811013e93e19a697fb7454e2db6a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a915811013e93e19a697fb7454e2db6a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a915811013e93e19a697fb7454e2db6a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a915811013e93e19a697fb7454e2db6a = L.geoJson(null, {
#                 onEachFeature: geo_json_a915811013e93e19a697fb7454e2db6a_onEachFeature,
#
#                 style: geo_json_a915811013e93e19a697fb7454e2db6a_styler,
#         });
#
#         function geo_json_a915811013e93e19a697fb7454e2db6a_add (data) {
#             geo_json_a915811013e93e19a697fb7454e2db6a
#                 .addData(data)
#                 .addTo(choropleth_7d144fcc19d4cb1876c5d0be532f397b);
#         }
#             geo_json_a915811013e93e19a697fb7454e2db6a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-51.65779741067889, 4.156232408053029], [-52.249337531123956, 3.241094468596245], [-52.55642473001842, 2.504705308437053], [-52.939657151894956, 2.124857692875636], [-53.41846513529531, 2.053389187015981], [-53.554839240113544, 2.334896551925951], [-53.77852067728892, 2.376702785650082], [-54.08806250671725, 2.105556545414629], [-54.524754197799716, 2.311848863123785], [-54.2697051662232, 2.732391669115046], [-54.181726040246275, 3.189779771330421], [-54.00693050801901,

# %% [markdown]
# ### Does the analysis answer any of your existing research questions?
#
# We saw previously that potential customers are interested in New boats in stock. This analysis shows us in which country newest boats are located. It's answering one of our first question telling us that most of the new Boats are located in Germany, Switzerland, Italy, Netherlands, Poland and Croatia.
#
# ### Does the analysis lead you to any new research questions?
#
# This analysis could lead to question like what country has the biggest quantity of new boats ?

# %%
m = folium.Map(location=[46.8155135,8.224471999999992],zoom_start=5, width=800, height=500, control_scale=True)
choropleth_price = folium.Choropleth(
    geo_data = europe_json,
    data=df,
    columns = ['Country', 'Length'],
    key_on = 'feature.properties.name',
    fill_color = "Reds",
    fill_opacity = .8,
    line_opacity = .5,
    legend_name = 'Length of the boats',
    highlight = True,
    name='choropleth',
    nan_fill_color="rgba(0, 0, 0, 0)"
    
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c1036c59136f2799535533a88a5b195 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c1036c59136f2799535533a88a5b195&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c1036c59136f2799535533a88a5b195 = L.map(
#                 &quot;map_8c1036c59136f2799535533a88a5b195&quot;,
#                 {
#                     center: [46.8155135, 8.224471999999992],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8c1036c59136f2799535533a88a5b195);
#
#
#
#
#
#             var tile_layer_7b5d3d11479378912832f1be36642342 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c1036c59136f2799535533a88a5b195);
#
#
#             var choropleth_ff44928817ba5407211a2f6631441383 = L.featureGroup(
#                 {}
#             ).addTo(map_8c1036c59136f2799535533a88a5b195);
#
#
#         function geo_json_23a40b2b1a023ed682ab13a1defcd6f7_styler(feature) {
#             switch(feature.properties.sovereignt) {
#                 case &quot;France&quot;: case &quot;Germany&quot;: case &quot;Austria&quot;: case &quot;Italy&quot;: case &quot;Switzerland&quot;: case &quot;Netherlands&quot;: case &quot;Croatia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee5d9&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Belgium&quot;: case &quot;Spain&quot;: case &quot;Denmark&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc9272&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Finland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fb6a4a&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Poland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcbba1&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Greece&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a50f15&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgba(0, 0, 0, 0)&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_23a40b2b1a023ed682ab13a1defcd6f7_highlighter(feature) {
#             switch(feature.properties.sovereignt) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_23a40b2b1a023ed682ab13a1defcd6f7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_23a40b2b1a023ed682ab13a1defcd6f7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_23a40b2b1a023ed682ab13a1defcd6f7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_23a40b2b1a023ed682ab13a1defcd6f7 = L.geoJson(null, {
#                 onEachFeature: geo_json_23a40b2b1a023ed682ab13a1defcd6f7_onEachFeature,
#
#                 style: geo_json_23a40b2b1a023ed682ab13a1defcd6f7_styler,
#         });
#
#         function geo_json_23a40b2b1a023ed682ab13a1defcd6f7_add (data) {
#             geo_json_23a40b2b1a023ed682ab13a1defcd6f7
#                 .addData(data)
#                 .addTo(choropleth_ff44928817ba5407211a2f6631441383);
#         }
#             geo_json_23a40b2b1a023ed682ab13a1defcd6f7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-51.65779741067889, 4.156232408053029], [-52.249337531123956, 3.241094468596245], [-52.55642473001842, 2.504705308437053], [-52.939657151894956, 2.124857692875636], [-53.41846513529531, 2.053389187015981], [-53.554839240113544, 2.334896551925951], [-53.77852067728892, 2.376702785650082], [-54.08806250671725, 2.105556545414629], [-54.524754197799716, 2.311848863123785], [-54.2697051662232, 2.732391669115046], [-54.181726040246275, 3.189779771330421], [-54.00693050801901,

# %% [markdown]
# ### Does the analysis answer any of your existing research questions?
#
# This analysis shows us in which country have boat with more length are located. It is interesting to see that Greece is on top of the chart here followed by Sweden and then Spain, Belgium, and Denmark. It is not answering any of our question but it's a relevant data to have in case we would like to share this data to the sales team in case they would like to segment the market.
#
# ### Does the analysis lead you to any new research questions?
#
# This analysis could lead to question like where are biggest or smallest boats located in the market ?
